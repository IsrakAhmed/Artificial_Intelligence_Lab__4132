# %%
import numpy as np
import matplotlib.pyplot as plt


def func1(x, w, b):
    return ((w * x) + b)

def func2(x):
    return x * x

def func3(x):
    return 1 / (1 + np.pow(np.e,(-x_values)))

def func4(x):
    return (np.pow(np.e,x) - np.pow(np.e,(-x))) / (np.pow(np.e,x) - np.pow(np.e,(-x)))

def func5(u):
    return 1 / (1 + np.pow(np.e,(-u)))

def func6(u):
    return (np.pow(np.e,u) - np.pow(np.e,(-u))) / (np.pow(np.e,u) + np.pow(np.e,(-u)))


plt.figure(figsize=(15, 12))

w = 1
b = 2

x_values = np.arange(-10,10,0.1)


func = func1(x_values,w,b)
plt.subplot(3,3,1)
plt.plot(x_values,func, label = "y = wx + b")
plt.title("y = wx + b")
plt.legend()
plt.grid()
plt.tight_layout()


func = func2(x_values)
plt.subplot(3,3,2)
plt.plot(x_values,func, label = "y = x^2")
plt.title("y = x^2")
plt.legend()
plt.grid()
plt.tight_layout()


func = func3(x_values)
plt.subplot(3,3,3)
plt.plot(x_values,func, label = "y = 1/ (1 + e^(-x))")
plt.title("y = 1/ (1 + e^(-x))")
plt.legend()
plt.grid()
plt.tight_layout()


func = func4(x_values)
plt.subplot(3,3,4)
plt.plot(x_values,func, label = "y = (e^x - e^(-x)) / (e^x - e^(-x))")
plt.title("y = (e^x - e^(-x)) / (e^x - e^(-x))")
plt.legend()
plt.grid()
plt.tight_layout()


fx = func1(x_values,w,b)
func = func5(fx)
plt.subplot(3,3,5)
plt.plot(x_values,func, label = "g(u) = 1/ (1 + e^(-u))")
plt.title("g(u) = 1/ (1 + e^(-u))")
plt.legend()
plt.grid()
plt.tight_layout()


w = 1
b = 2
fx = func1(x_values,w,b)
func = func6(fx)
plt.subplot(3,3,6)
plt.plot(x_values,func, label = "g(u) = (e^u - e^(-u)) / (e^u + e^(-u))")
plt.title("g(u) = (e^u - e^(-u)) / (e^u + e^(-u))")
plt.legend()
plt.grid()
plt.tight_layout()


w1 = 5
b1 = 8
fx = func1(x_values,w1,b1)
y1 = func5(fx)
w2 = 10
b2 = 12
fx = func1(x_values,w2,b2)
y2 = func5(fx)
w3 = 9
b = 6
w4 = 7
f3v = w3 * y1 + w4 * y2 + b
func = func3(f3v)
plt.subplot(3,3,7)
plt.plot(x_values,func, label = "g(u) = (e^u - e^(-u)) / (e^u + e^(-u))")
plt.title("g(u) = (e^u - e^(-u)) / (e^u + e^(-u))")
plt.legend()
plt.grid()
plt.tight_layout()


plt.show()
